# %% [markdown]
# ## IMPORTS

# %%
import numpy as np
from scipy.stats import zscore
import pandas as pd
import altair as alt
alt.data_transformers.enable("vegafusion")

gym_data = pd.read_csv(
    "/Users/yusufahmed/Documents/PreCourseLearning/week8_data_analysis_2/Workshop/Workshop_folder/gym_data.csv")

# %%
gym_data.describe()
# Out:
#         Unnamed: 0          Age   Height (m)      Avg_BPM  \
# count  1324.000000  1324.000000  1324.000000  1324.000000
# mean    661.500000    38.486405     1.723165   143.861782
# std     382.350189    22.602530     0.129968    14.356799
# min       0.000000  -168.000000     1.500000   120.000000
# 25%     330.750000    28.000000     1.620000   132.000000
# 50%     661.500000    39.000000     1.710000   143.000000
# 75%     992.250000    50.000000     1.810000   157.000000
# max    1323.000000   248.000000     2.000000   169.000000
#
#        Session_Duration (hours)
# count               1324.000000
# mean                   1.332509
# std                    1.051352
# min                    0.024549
# 25%                    1.030000
# 50%                    1.260000
# 75%                    1.470000
# max                   26.453492

# %%
gym_data["Session_Duration_zscore"] = zscore(gym_data["Session_Duration (hours)"])
gym_data = gym_data[(gym_data["Session_Duration_zscore"].abs() < 3)]
gym_data.describe()
gym_data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1297 entries, 0 to 1323
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                1297 non-null   int64
#  1   Age                       1297 non-null   int64
#  2   Gender                    1297 non-null   str
#  3   Height (m)                1297 non-null   float64
#  4   Avg_BPM                   1297 non-null   int64
#  5   Session_Duration (hours)  1297 non-null   float64
#  6   Workout_Type              894 non-null    str
#  7   Session_Duration_zscore   1297 non-null   float64
# dtypes: float64(3), int64(3), str(2)
# memory usage: 102.7 KB

# %%
workout_type = gym_data["Workout_Type"].value_counts()
print(workout_type)
# Out:
# Workout_Type
# Cardio       226
# Strength     222
# HIIT         203
# Yoga         195
# strength       4
# yoga           3
# Yogqa          2
# cardio         2
# CARDIO         2
# Strenggh       2
# Cardiio        2
# STRENGTH       2
# HI IT          2
# Ykoga          1
# Cradio         1
# GIIT           1
# Strehngth      1
# Cadrio         1
# Strengthh      1
# Stregth        1
# Yogaa          1
# hiit           1
# Cardoi         1
# Carddio        1
# Strengtu       1
# Y oga          1
# Streength      1
# Stren gth      1
# Crdio          1
# Yo9a           1
# Sttrength      1
# oga            1
# UHIIT          1
# Strentgh       1
# Gardio         1
# YIIT           1
# Str ength      1
# Catdio         1
# Ypoga          1
# GYoga          1
# Name: count, dtype: int64

# %%
gym_data["Workout_Type"] = gym_data["Workout_Type"].apply(lambda x: str(x).lower().strip())
print(gym_data["Workout_Type"].value_counts())
# Out:
#   Cell In[30], line 4
#     if (x[0] == "s") and (x[1] == "t"):
#     ^
# SyntaxError: invalid syntax
